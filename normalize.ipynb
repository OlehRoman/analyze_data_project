# %% [markdown]
# # Імпорти

# %%
import pandas as pd
import numpy as np
import glob
import os
import csv

# %% [markdown]
# # Огляд файлів

# %%
start_data_path = 'data/accidentlvivmth2023.csv'

df = pd.read_csv(start_data_path, encoding='cp1251', sep = ';')

print(df.head(), '\n')
print(df.info(), '\n')
print(df.isnull().sum(), '\n')
print(df.nunique())
# Out:
#   accidentDate accidentTime accidentDay settlementType settlement  \
# 0   2023-01-09     20:10:00   понеділок          місто      Львів
# 1   2023-01-31     11:03:00    вівторок          місто      Львів
# 2   2023-01-13     23:26:00    п'ятниця          місто      Львів
# 3   2023-01-20     21:12:00    п'ятниця          місто      Львів
# 4   2023-01-15     18:52:00      неділя          місто      Львів
#
#        district streetType         streetName houseNumber  \
# 0  Франківський     вулиця        Кобилиці Л.          19
# 1     Галицький     вулиця       Політехнічна           7
# 2  Франківський     вулиця          Стрийська        280а
# 3  Личаківський     вулиця  Глинянський Тракт           8
# 4   Залізничний     вулиця     Кульпарківська         NaN
#
#                             locationComments  ...  \
# 0                                        NaN  ...
# 1                                        NaN  ...
# 2                                        NaN  ...
# 3                                        NaN  ...
# 4  вул. Кульпарківська - вул. Перфецького Л.  ...
#
#                                    mainAccidentCause totalParticipantsAmount  \
# 0                      порушення правил маневрування                       1
# 1  перехід у невстановленому місці, неочікуваний ...                       2
# 2                      порушення правил маневрування                       1
# 3                      порушення правил маневрування                       2
# 4              неочікуваний вихід на проїзну частину                       2
#
#    injuryStatusParticipant1 injuryStatusParticipant2 injuryStatusParticipant3  \
# 0         легко травмований                      NaN                      NaN
# 1             без ушкоджень        легко травмований                      NaN
# 2         легко травмований                      NaN                      NaN
# 3             без ушкоджень        легко травмований                      NaN
# 4             без ушкоджень        легко травмований                      NaN
#
#   injuryStatusParticipant4 injuryStatusParticipant5 injuryStatusParticipant6  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#     latitude  longitude
# 0  49.816849  23.998309
# 1  49.834052  24.014472
# 2  49.789604  24.015126
# 3  49.836560  24.071630
# 4  49.815014  23.985659
#
# [5 rows x 21 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   accidentDate              691 non-null    object
#  1   accidentTime              691 non-null    object
#  2   accidentDay               691 non-null    object
#  3   settlementType            691 non-null    object
#  4   settlement                691 non-null    object
#  5   district                  691 non-null    object
#  6   streetType                691 non-null    object
#  7   streetName                687 non-null    object
#  8   houseNumber               540 non-null    object
#  9   locationComments          97 non-null     object
#  10  accidentType              691 non-null    object
#  11  mainAccidentCause         691 non-null    object
#  12  totalParticipantsAmount   691 non-null    int64
#  13  injuryStatusParticipant1  691 non-null    object
#  14  injuryStatusParticipant2  656 non-null    object
#  15  injuryStatusParticipant3  135 non-null    object
#  16  injuryStatusParticipant4  31 non-null     object
#  17  injuryStatusParticipant5  7 non-null      object
#  18  injuryStatusParticipant6  3 non-null      object
#  19  latitude                  691 non-null    float64
#  20  longitude                 691 non-null    float64
# dtypes: float64(2), int64(1), object(18)
# memory usage: 113.5+ KB
# None
#
# accidentDate                  0
# accidentTime                  0
# accidentDay                   0
# settlementType                0
# settlement                    0
# district                      0
# streetType                    0
# streetName                    4
# houseNumber                 151
# locationComments            594
# accidentType                  0
# mainAccidentCause             0
# totalParticipantsAmount       0
# injuryStatusParticipant1      0
# injuryStatusParticipant2     35
# injuryStatusParticipant3    556
# injuryStatusParticipant4    660
# injuryStatusParticipant5    684
# injuryStatusParticipant6    688
# latitude                      0
# longitude                     0
# dtype: int64
#
# accidentDate                304
# accidentTime                420
# accidentDay                   7
# settlementType                3
# settlement                   13
# district                      7
# streetType                    5
# streetName                  193
# houseNumber                 212
# locationComments             82
# accidentType                 27
# mainAccidentCause            73
# totalParticipantsAmount       6
# injuryStatusParticipant1      5
# injuryStatusParticipant2      6
# injuryStatusParticipant3      4
# injuryStatusParticipant4      2
# injuryStatusParticipant5      1
# injuryStatusParticipant6      1
# latitude                    678
# longitude                   676
# dtype: int64

# %% [markdown]
# # Об'єднання файлів в один

# %%
csv_mix = os.path.join('data', '*.csv')

file_list = glob.glob(csv_mix)

print(f'{len(file_list)} files found ')
print(file_list)
# Out:
# 8 files found
# ['data\\accidentlviv2017.csv', 'data\\accidentlviv2018.csv', 'data\\accidentlviv2019.csv', 'data\\accidentlviv2020.csv', 'data\\accidentlvivmth2021.csv', 'data\\accidentlvivmth2022.csv', 'data\\accidentlvivmth2023.csv', 'data\\dtp2024public.csv']

# %%
list_of_files = []

for file in file_list:

    with open(file, 'r', encoding='cp1251') as f:

        header_line = f.readline()
        sniffer = csv.Sniffer()
        dialect = sniffer.sniff(header_line)
        delimiter = dialect.delimiter
        print(f'{delimiter} : {os.path.basename(file)}')

    df_temp = pd.read_csv(
        file,
        encoding='cp1251',
        sep = delimiter,
        low_memory=False
    )

    list_of_files.append(df_temp)

df_combined = pd.concat(list_of_files, axis=0, ignore_index=True)
print(df_combined.info(), '\n')

df_combined.to_csv('combined_accidents.csv', sep = ';', index = False, encoding = 'utf-8-sig')

print(f'Combined accidents data saved to combined_accidents.csv')
# Out:
# , : accidentlviv2017.csv
# , : accidentlviv2018.csv
# , : accidentlviv2019.csv
# , : accidentlviv2020.csv
# , : accidentlvivmth2021.csv
# , : accidentlvivmth2022.csv
# ; : accidentlvivmth2023.csv
# ; : dtp2024public.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5908 entries, 0 to 5907
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   accidentDate               5908 non-null   object
#  1   accidentTime               5908 non-null   object
#  2   accidentDay                5908 non-null   object
#  3   settlementType             5908 non-null   object
#  4   settlement                 5908 non-null   object
#  5   district                   5898 non-null   object
#  6   streetType                 5897 non-null   object
#  7   streetName                 5891 non-null   object
#  8   houseNumber                4461 non-null   object
#  9   locationComments           983 non-null    object
#  10  accidentType               5908 non-null   object
#  11  mainAccidentCause          5456 non-null   object
#  12  totalParticipantsAmount    5908 non-null   int64
#  13  injuryStatusParticipant1   5907 non-null   object
#  14  injuryStatusParticipant2   5582 non-null   object
#  15  injuryStatusParticipant3   1273 non-null   object
#  16  injuryStatusParticipant4   403 non-null    object
#  17  injuryStatusParticipant5   121 non-null    object
#  18  injuryStatusParticipant6   43 non-null     object
#  19  injuryStatusParticipant7   22 non-null     object
#  20  injuryStatusParticipant8   12 non-null     object
#  21  injuryStatusParticipant9   7 non-null      object
#  22  latitude                   5905 non-null   float64
#  23  longitude                  5905 non-null   float64
#  24  injuryStatusParticipant10  3 non-null      object
#  25  injuryStatusParticipant11  3 non-null      object
#  26  injuryStatusParticipant12  1 non-null      object
#  27  injuryStatusParticipant13  1 non-null      object
#  28  injuryStatusParticipant14  1 non-null      object
#  29  injuryStatusParticipant15  1 non-null      object
#  30  injuryStatusParticipant16  1 non-null      object
#  31  injuryStatusParticipant17  1 non-null      object
#  32  injuryStatusParticipant18  1 non-null      object
#  33  injuryStatusParticipant19  1 non-null      object
#  34  injuryStatusParticipant20  1 non-null      object
# dtypes: float64(2), int64(1), object(32)
# memory usage: 1.6+ MB
# None
#
# Combined accidents data saved to combined_accidents.csv

# %% [markdown]
# # Підготовка даних

# %% [markdown]
# #### Зменшуємо к-сть колонок InjuryStatus і трансформує у колонки вигляду Count_'status'

# %%
df = pd.read_csv('combined_accidents.csv', sep = ';', low_memory=False)

injury_cols = df.filter(like='injuryStatusParticipant').columns

all_unique_values = pd.Series(df[injury_cols].values.ravel()).unique()
print("Unique item in InjuryStatusParticipation")
print(all_unique_values)
# Out:
# Unique item in InjuryStatusParticipation
# ['легко травмований' 'без ушкоджень' nan 'тяжко травмований'
#  'помер на місці дтп' 'помер у лікарні протягом 30 діб'
#  'помер по дорозі в лікарню']

# %%
injury_mapping = {
    'помер на місці дтп': 'Загинув',
    'помер у лікарні протягом 30 діб': 'Загинув',
    'помер по дорозі в лікарню': 'Загинув',

    'легко травмований': 'Легко травмований',
    'тяжко травмований': 'Тяжко травмований',
    'без ушкоджень': 'Без ушкоджень'
}

injury_counts_df = df.apply(lambda row: row[injury_cols].value_counts(), axis = 1)

injury_counts_df = injury_counts_df.fillna(0).astype(int)

injury_counts_df = injury_counts_df.rename(columns = {col: f'Count_{col}' for col in injury_counts_df.columns if col is not np.nan})

# %%
injury_cols = df.filter(like='injuryStatusParticipant').columns


print(f"Знайдено {len(injury_cols)} колонок зі статусами травм.")

df[injury_cols] = df[injury_cols].replace(injury_mapping)

all_unique_values = pd.Series(df[injury_cols].values.ravel()).unique()
print("\n--- Унікальні статуси ПІСЛЯ об'єднання ---")
print(all_unique_values)

print("\nПочинаю підрахунок об'єднаних статусів по кожному ДТП...")

injury_counts_df = df.apply(lambda row: row[injury_cols].value_counts(), axis=1)

injury_counts_df = injury_counts_df.fillna(0).astype(int)

injury_counts_df = injury_counts_df.rename(columns={
    col: f'Count_{col}' for col in injury_counts_df.columns if col is not np.nan
})

if np.nan in injury_counts_df.columns:
    injury_counts_df = injury_counts_df.drop(columns=[np.nan])
if 'Count_nan' in injury_counts_df.columns:
    injury_counts_df = injury_counts_df.drop(columns=['Count_nan'])

print("Створено нові колонки з підрахунками:")
print(injury_counts_df.head())

df= pd.concat([df, injury_counts_df], axis=1)

df = df.drop(columns=injury_cols)

print("\n--- Фінальна інформація про DataFrame (після очистки) ---")
df.info()
# Out:
# Знайдено 20 колонок зі статусами травм.
#
# --- Унікальні статуси ПІСЛЯ об'єднання ---
# ['Легко травмований' 'Без ушкоджень' nan 'Тяжко травмований' 'Загинув']
#
# Починаю підрахунок об'єднаних статусів по кожному ДТП...
# Створено нові колонки з підрахунками:
#    Count_Без ушкоджень  Count_Загинув  Count_Легко травмований  \
# 0                    1              0                        2
# 1                    1              0                        5
# 2                    1              0                        1
# 3                    1              0                        0
# 4                    1              0                        1
#
#    Count_Тяжко травмований
# 0                        0
# 1                        0
# 2                        0
# 3                        1
# 4                        0
#
# --- Фінальна інформація про DataFrame (після очистки) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5908 entries, 0 to 5907
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   accidentDate             5908 non-null   object
#  1   accidentTime             5908 non-null   object
#  2   accidentDay              5908 non-null   object
#  3   settlementType           5908 non-null   object
#  4   settlement               5908 non-null   object
#  5   district                 5898 non-null   object
#  6   streetType               5897 non-null   object
#  7   streetName               5891 non-null   object
#  8   houseNumber              4461 non-null   object
#  9   locationComments         983 non-null    object
#  10  accidentType             5908 non-null   object
#  11  mainAccidentCause        5456 non-null   object
#  12  totalParticipantsAmount  5908 non-null   int64
#  13  latitude                 5905 non-null   float64
#  14  longitude                5905 non-null   float64
#  15  Count_Без ушкоджень      5908 non-null   int64
#  16  Count_Загинув            5908 non-null   int64
#  17  Count_Легко травмований  5908 non-null   int64
#  18  Count_Тяжко травмований  5908 non-null   int64
# dtypes: float64(2), int64(5), object(12)
# memory usage: 877.1+ KB

# %% [markdown]
# #### Додаємо колонку вигляду "Чи трапилося дтп на перехресті"

# %%
df['Is_Intersection'] = df['locationComments'].str.contains(
    'перехрестя',
    case=False,
    na=False
).astype(int)

print(f"\nВсього знайдено рядків з 'перехрестя': {df['Is_Intersection'].sum()}")
# Out:
# Всього знайдено рядків з 'перехрестя': 478

# %% [markdown]
# #### Трансформуємо дату й час

# %%
df['accidentDate'] = pd.to_datetime(df['accidentDate'], format='%Y-%m-%d')

df['Year'] = df['accidentDate'].dt.year
df['Month'] = df['accidentDate'].dt.month
df['DayOfWeek'] = df['accidentDate'].dt.dayofweek # 0=Пон, 1=Вів, ..., 6=Нед

df['Hour'] = pd.to_datetime(df['accidentTime'], format='mixed').dt.hour

# %% [markdown]
# ### Видаляємо непотрібні колонки

# %%
cols_to_drop = ['houseNumber', 'locationComments', 'streetType','accidentDate', 'accidentTime']

df = df.drop(columns=cols_to_drop)
print(f"Видалено непотрібні колонки: {cols_to_drop}")
# Out:
# Видалено непотрібні колонки: ['houseNumber', 'locationComments', 'streetType', 'accidentDate', 'accidentTime']

# %% [markdown]
# #### Заливаємо" NaN у категорійних фічах

# %%
cols_to_fill = ['district', 'streetName', 'mainAccidentCause']

for col in cols_to_fill:
    df[col] = df[col].fillna('Невідомо')
print(f"Заповнено NaN у колонках: {cols_to_fill}")
# Out:
# Заповнено NaN у колонках: ['district', 'streetName', 'mainAccidentCause']

# %% [markdown]
# #### Видаляємо рядки, які не мають заповнених координат ('latitude', 'longitude')

# %%
rows_before = len(df)
df = df.dropna(subset=['latitude', 'longitude'])
rows_after = len(df)
print(f"Видалено {rows_before - rows_after} рядків без координат.")
# Out:
# Видалено 3 рядків без координат.

# %%
print(df.nunique())
# Out:
# accidentDay                   7
# settlementType                3
# settlement                   19
# district                      8
# streetName                  495
# accidentType                 41
# mainAccidentCause           264
# totalParticipantsAmount      11
# latitude                   5166
# longitude                  5136
# Count_Без ушкоджень           7
# Count_Загинув                 3
# Count_Легко травмований      10
# Count_Тяжко травмований       6
# Is_Intersection               2
# Year                          8
# Month                        12
# DayOfWeek                     7
# Hour                         24
# dtype: int64

# %%
print(df['settlement'].value_counts())
print(df['settlementType'].value_counts())
# Out:
# settlement
# Львів               5687
# Винники               56
# Брюховичі             36
# Малехів               28
# Рудне                 23
# Дубляни               15
# Рясне-Руське          13
# Підбірці               9
# Зашків                 7
# Великі Грибовичі       6
# Пасіки-Зубрицькі       5
# Гряда                  4
# Лисиничі               4
# Сокільники             4
# Малі Підліски          3
# Збиранка               2
# Солонка                1
# Підрясне               1
# Завадів                1
# Name: count, dtype: int64
# settlementType
# місто     5760
# село        86
# селище      59
# Name: count, dtype: int64

# %%
df['settlement_grouped'] = df['settlement'].apply(lambda x: 'Львів' if x == 'Львів' else 'Передмістя')

df = df.drop(columns=['settlement', 'settlementType'])

print(df['settlement_grouped'].value_counts())
# Out:
# settlement_grouped
# Львів         5687
# Передмістя     218
# Name: count, dtype: int64

# %%
def clean_accident_type(val):
    val = str(val).lower()
    if 'пішоход' in val:
        return 'Наїзд на пішохода'
    elif 'велосипед' in val:
        return 'Наїзд на велосипедиста'
    elif 'зіткнення' in val:
        return 'Зіткнення автомобілів'
    elif 'перешкод' in val or 'огородження' in val or 'дерево' in val or 'знак' in val:
        return 'Наїзд на перешкоду'
    elif 'пасажир' in val:
        return 'Падіння пасажира'
    elif 'перекидання' in val:
        return 'Перекидання'
    else:
        return 'Інше'

def clean_accident_cause(val):
    val = str(val).lower()
    if 'маневрування' in val:
        return 'Порушення маневрування'
    elif 'швидкост' in val:
        return 'Перевищення швидкості'
    elif 'дистанц' in val:
        return 'Недотримання дистанції'
    elif 'перехрест' in val:
        return 'Порушення проїзду перехресть'
    elif 'пішохід' in val: # Тут і про переходи, і про пішоходів
        return 'Порушення проїзду переходів'
    elif 'нетверезому' in val:
        return 'П\'яне водіння'
    else:
        return 'Інше'

# Застосовуємо очистку
df['Simple_Type'] = df['accidentType'].apply(clean_accident_type)
df['Simple_Cause'] = df['mainAccidentCause'].apply(clean_accident_cause)

# Дивимось результат
print("--- ТИПИ ---")
print(df['Simple_Type'].value_counts())
print("\n--- ПРИЧИНИ ---")
print(df['Simple_Cause'].value_counts())
# Out:
# --- ТИПИ ---
# Simple_Type
# Наїзд на пішохода         2852
# Зіткнення автомобілів     1956
# Падіння пасажира           325
# Наїзд на перешкоду         322
# Наїзд на велосипедиста     256
# Інше                       107
# Перекидання                 87
# Name: count, dtype: int64
#
# --- ПРИЧИНИ ---
# Simple_Cause
# Порушення маневрування          2227
# Інше                            1226
# Перевищення швидкості           1073
# Порушення проїзду переходів      697
# Порушення проїзду перехресть     365
# Недотримання дистанції           285
# П'яне водіння                     32
# Name: count, dtype: int64

# %%
print(df['accidentType'].value_counts())
print(df['mainAccidentCause'].value_counts())
print(df['district'].value_counts())
# Out:
# accidentType
# наїзд на пішохода - пішохід рухався у попутному напрямку                                                       1290
# зіткнення бокове                                                                                               1139
# наїзд на пішохода - на нерегульованому пішохідному переході                                                     523
# зіткнення лобове                                                                                                444
# наїзд на пішохода - пішохід рухався у зустрічному напрямку                                                      381
# падіння пасажира                                                                                                325
# наїзд на інші види перешкод                                                                                     288
# зіткнення з задньою частиною тз                                                                                 222
# наїзд на пішохода - на регульованому пішохідному переході                                                       194
# наїзд на велосипедиста - велосипедист рухався у попутному напрямку                                              176
# наїзд на пішохода - стояв на проїздній частині                                                                  170
# зіткнення з задньою частиною ТЗ                                                                                 146
# наїзд на пішохода - пішохід переходив дорогу поза межами піш.переходу                                            89
# наїзд на транспортний засіб, що стоїть - по ходу руху                                                            87
# перекидання тз                                                                                                   82
# наїзд на пішохода - пішохід на тротуарі чи велосипедній доріжці                                                  63
# наїзд на велосипедиста - поза межами велосипедної доріжки                                                        61
# наїзд на пішохода - пішохід переходив дорогу поза межами пішохідного переходу                                    52
# наїзд на пішохода                                                                                                39
# наїзд на пішохода - пішохід переходив дорогу поза межами піш. переходу                                           18
# наїзд на дерево                                                                                                  15
# наїзд на пішохода - пішоходний перехід, тз здійснював поворот вліво (вправо)                                     13
# наїзд на дорожний знак, бордюрний камінь                                                                         11
# наїзд на велосипедиста - велосипедист рухався у зустрічному напрямку                                             11
# наїзд на велосипедиста - на велосипедній доріжці                                                                  8
# наїзд на пішохода - лежав на дорозі                                                                               7
# наїзд на пішохода - пішохід на зупинці громадського транспорту                                                    7
# наїзд на дорожне огородження                                                                                      7
# наїзд на опори (леп, телефонних та телеграфних ліній, рекламоносіїв, щогли антен моб. зв'язку, тощо)              6
# перекидання ТЗ                                                                                                    5
# зіткнення                                                                                                         5
# наїзд на опори (леп, телефонних та телеграфних ліній, рекламоносіїв, щогли антен мобільного зв'язку, тощо)        5
# наїзд на пішохода - стояв на проїжджій частині                                                                    4
# наїзд на опори (ЛЕП, телефонних та телеграфних ліній, рекламоносіїв, щогли антен моб. зв'язку, тощо)              3
# наїзд на пішохода - пішохідний перехід, ТЗ здійснював поворот вліво (вправо)                                      2
# наїзд на опори ( леп, телефонних та телеграфних ліній, рекламоносіїв, щогли антен моб. зв'язку, тощо )            2
# наїзд на опори ( леп, телефонних та телеграфних ліній, рекламоносіїв, щогли антен мобільного зв'язку, тощо)       1
# падіння вантажів                                                                                                  1
# накїзд на інші види перешкод                                                                                      1
# наїзд на транспортний засіб, що стоїть - під час відкривання дверей                                               1
# наїзд на тварин - дика                                                                                            1
# Name: count, dtype: int64
# mainAccidentCause
# порушення правил маневрування                                                                                         1886
# перевищення безпечної швидкості                                                                                        621
# порушення правил проїзду пішохідних переходів                                                                          620
# Невідомо                                                                                                               452
# порушення правил проїзду перехресть                                                                                    325
#                                                                                                                       ...
# порушення правил проїзду залізничних переїздів                                                                           1
# керування транспортним засобом у нетверезому стані, перевищення безпечної швидкості, порушення правил маневрування       1
# ненадання переваги в русі при виїзді на дорогу з прилеглої території                                                     1
# порушення вимог дорожніх знаків пріоритету при проїзді перехрестя                                                        1
# порушення ПДР пішоходами у стані сп'яніння                                                                               1
# Name: count, Length: 264, dtype: int64
# district
# Шевченківський    1225
# Франківський      1034
# Залізничний        996
# Сихівський         972
# Галицький          884
# Личаківський       783
# Невідомо            10
# шевченківський       1
# Name: count, dtype: int64

# %%
df.to_csv('accident_clear_data.csv', sep=';', index=False, encoding='utf-8-sig')
print(f"\nЧистий DataFrame збережено як accident_clear_data.csv ")
# Out:
# Чистий DataFrame збережено як accident_clear_data.csv
